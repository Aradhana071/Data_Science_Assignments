# %%
data = pd.read_csv("50_Startups.csv")
data.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing Spend  50 non-null     float64
#  3   State            50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
data['State']=data['State'].astype('category')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing Spend  50 non-null     float64
#  3   State            50 non-null     category
#  4   Profit           50 non-null     float64
# dtypes: category(1), float64(4)
# memory usage: 1.9 KB

# %%
data.isna().sum()
# Out:
# R&D Spend          0
# Administration     0
# Marketing Spend    0
# State              0
# Profit             0
# dtype: int64

# %%
data.corr()
# Out:
#                  R&D Spend  Administration  Marketing Spend    Profit
# R&D Spend         1.000000        0.241955         0.724248  0.972900
# Administration    0.241955        1.000000        -0.032154  0.200717
# Marketing Spend   0.724248       -0.032154         1.000000  0.747766
# Profit            0.972900        0.200717         0.747766  1.000000

# %%
sns.set_style(style='darkgrid')
sns.pairplot(data)

# %%
data1=data.copy()

# %%
data1=data1.rename({'R&D Spend':'R&D'},axis=1)
data1=data1.rename({'Administration':'Admin'},axis=1)
data1=data1.rename({'Marketing Spend':'MktSpnd'},axis=1)

# %%
data1
# Out:
#           R&D      Admin    MktSpnd       State     Profit
# 0   165349.20  136897.80  471784.10    New York  192261.83
# 1   162597.70  151377.59  443898.53  California  191792.06
# 2   153441.51  101145.55  407934.54     Florida  191050.39
# 3   144372.41  118671.85  383199.62    New York  182901.99
# 4   142107.34   91391.77  366168.42     Florida  166187.94
# 5   131876.90   99814.71  362861.36    New York  156991.12
# 6   134615.46  147198.87  127716.82  California  156122.51
# 7   130298.13  145530.06  323876.68     Florida  155752.60
# 8   120542.52  148718.95  311613.29    New York  152211.77
# 9   123334.88  108679.17  304981.62  California  149759.96
# 10  101913.08  110594.11  229160.95     Florida  146121.95
# 11  100671.96   91790.61  249744.55  California  144259.40
# 12   93863.75  127320.38  249839.44     Florida  141585.52
# 13   91992.39  135495.07  252664.93  California  134307.35
# 14  119943.24  156547.42  256512.92     Florida  132602.65
# ...

# %%
X = data[['R&D Spend','Administration', 'Marketing Spend']]
Y = data[['Profit']]

# %%
import statsmodels.formula.api as smf 
model = smf.ols('Y~X',data=data).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      Y   R-squared:                       0.951
# Model:                            OLS   Adj. R-squared:                  0.948
# Method:                 Least Squares   F-statistic:                     296.0
# Date:                Mon, 07 Feb 2022   Prob (F-statistic):           4.53e-30
# Time:                        23:46:07   Log-Likelihood:                -525.39
# No. Observations:                  50   AIC:                             1059.
# Df Residuals:                      46   BIC:                             1066.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   5.012e+04   6572.353      7.626      0.000    3.69e+04    6.34e+04
# ...

# %% [markdown]
# #### As we can see that Rsq value is acceptable, but all p values are not acceptable. Hence there is a multicolinearity

# %% [markdown]
# ### Finding Cooks distance

# %%
model_influence = model.get_influence()
(c, _) = model_influence.cooks_distance

# %%
ig = plt.subplots(figsize=(20, 7))
plt.stem(np.arange(len(data)), np.round(c, 3))
plt.xlabel('Row index')
plt.ylabel('Cooks Distance')
plt.show()

# %%
(np.argmax(c),np.max(c))
# Out:
# (49, 0.28808229275432634)

# %%
infl.plot_influence()

# %% [markdown]
# #### Index 46 and 48 have high cook distance

# %%
R = data['R&D Spend']
A = data['Administration']
M = data['Marketing Spend']
P = data['Profit']

# %%
Rsq = smf.ols('R~A+M',data=data).fit().rsquared  
vif_R = 1/(1-Rsq)

Asq = smf.ols('A~R+M',data=data).fit().rsquared  
vif_A = 1/(1-Asq)

Msq = smf.ols('M~R+A',data=data).fit().rsquared  
vif_M = 1/(1-Rsq)

# %%
d1 = {'Variables':['R','A','M'],'VIF':[vif_R,vif_A,vif_M]}
Vif_frame = pd.DataFrame(d1)  
Vif_frame
# Out:
#   Variables       VIF
# 0         R  2.468903
# 1         A  1.175091
# 2         M  2.468903

# %% [markdown]
# #### As we can see that VIF for Administration is low

# %%
datanew = data[['R&D Spend', 'Marketing Spend', 'Profit']]

# %%
datanew
# Out:
#     R&D Spend  Marketing Spend     Profit
# 0   165349.20        471784.10  192261.83
# 1   162597.70        443898.53  191792.06
# 2   153441.51        407934.54  191050.39
# 3   144372.41        383199.62  182901.99
# 4   142107.34        366168.42  166187.94
# 5   131876.90        362861.36  156991.12
# 6   134615.46        127716.82  156122.51
# 7   130298.13        323876.68  155752.60
# 8   120542.52        311613.29  152211.77
# 9   123334.88        304981.62  149759.96
# 10  101913.08        229160.95  146121.95
# 11  100671.96        249744.55  144259.40
# 12   93863.75        249839.44  141585.52
# 13   91992.39        252664.93  134307.35
# 14  119943.24        256512.92  132602.65
# 15  114523.61        261776.23  129917.04
# 16   78013.11        264346.06  126992.93
# 17   94657.16        282574.31  125370.37
# 18   91749.16        294919.57  124266.90
# 19   86419.70             0.00  122776.86
# 20   76253.86        298664.47  118474.03
# ...

# %%
datanew1=datanew.drop(datanew.index[[48,49]],axis=0).reset_index()

# %%
datanew1
# Out:
#     index  R&D Spend  Marketing Spend     Profit
# 0       0  165349.20        471784.10  192261.83
# 1       1  162597.70        443898.53  191792.06
# 2       2  153441.51        407934.54  191050.39
# 3       3  144372.41        383199.62  182901.99
# 4       4  142107.34        366168.42  166187.94
# 5       5  131876.90        362861.36  156991.12
# 6       6  134615.46        127716.82  156122.51
# 7       7  130298.13        323876.68  155752.60
# 8       8  120542.52        311613.29  152211.77
# 9       9  123334.88        304981.62  149759.96
# 10     10  101913.08        229160.95  146121.95
# 11     11  100671.96        249744.55  144259.40
# 12     12   93863.75        249839.44  141585.52
# 13     13   91992.39        252664.93  134307.35
# 14     14  119943.24        256512.92  132602.65
# 15     15  114523.61        261776.23  129917.04
# 16     16   78013.11        264346.06  126992.93
# 17     17   94657.16        282574.31  125370.37
# ...

# %%
X = datanew1[['R&D Spend', 'Marketing Spend']]
Y = datanew1[['Profit']]

# %%
import statsmodels.formula.api as smf 
model1 = smf.ols('Y~X',data=datanew1).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      Y   R-squared:                       0.951
# Model:                            OLS   Adj. R-squared:                  0.948
# Method:                 Least Squares   F-statistic:                     296.0
# Date:                Mon, 07 Feb 2022   Prob (F-statistic):           4.53e-30
# Time:                        23:46:09   Log-Likelihood:                -525.39
# No. Observations:                  50   AIC:                             1059.
# Df Residuals:                      46   BIC:                             1066.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   5.012e+04   6572.353      7.626      0.000    3.69e+04    6.34e+04
# ...

# %%
model_influence1 = model1.get_influence()
(c_V, _) = model_influence.cooks_distance

# %%
fig= plt.subplots(figsize=(20,7))
plt.stem(np.arange(len(datanew)),np.round(c_V,3));
plt.xlabel('Row index')
plt.ylabel('Cooks Distance');

# %%
(np.argmax(c_V),np.max(c_V))
# Out:
# (49, 0.28808229275432634)

# %% [markdown]
# #### Thus we can finalise the mode1 as final model.
